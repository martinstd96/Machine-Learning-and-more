# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime as dt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %matplotlib inline

#filtrado de warnings
warnings.filterwarnings('ignore')

# haciendo los graficos un poco mas bonitos en matplotlib
plt.style.use('default') 
#plt.rcParams['figure.figsize'] = (20, 10)

# seteando tipo de grid en seaborn
sns.set_theme(style='ticks', palette=None, font_scale=.9) 

# elimino la notacion cientifica en los outputs en pandas
pd.options.display.float_format = '{:20,.2f}'.format

# %% [markdown]
# #N5 - Utilizando los textos de las reviews para realizar consultas por texto y empleando las técnicas de NLP(TF-IDF), de modo que la query “bad smell” devuelva el “business_id” que haya recibido una crítica acerca una experiencia de malos olores en el local.

# %%
review_df_business_text = pd.read_csv('/content/drive/MyDrive/TP_Datos_1C2022/review.csv', usecols=['business_id', 'text'])

# %%
review_df_business_text.head()
# Out:
#               business_id                                               text
# 0  XQfwVwDr-v0ZS3_CbbE5Xw  If you decide to eat here, just be aware it is...
# 1  e4Vwtrqf-wpJfwesgvdgxQ  Cute interior and owner (?) gave us tour of up...
# 2  cPepkJeRMtHapc_b2Oe_dw  I was really between 3 and 4 stars for this on...
# 3  bMratNjTG5ZFEA6hVyr-xQ  First time there and it was excellent!!! It fe...
# 4  bbEXAEFr4RYHLlZ-HFssTA  Great burgers,fries and salad!  Burgers have a...

# %%
review_df_business_text.text.hasnans
# Out:
# False

# %%
max_features=len(review_df_business_text.text)*.1
max_features
# Out:
# 383810.5

# %% [markdown]
# Me fije eso para usar el 10% de la cantidad de textos

# %%
tf_idf_vectorizer = TfidfVectorizer(lowercase=True, stop_words='english', max_features=383810)

# %%
tf_idf_matrix = tf_idf_vectorizer.fit_transform(review_df_business_text.text)

# %%
nbrs_idf = NearestNeighbors(metric='cosine', algorithm='brute')
nbrs_idf.fit(tf_idf_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query = tf_idf_vectorizer.transform(["bad smell"])
distances, indices = nbrs_idf.kneighbors(query, n_neighbors=3)
print(distances[0])
# Out:
# [0.32317411 0.33595894 0.35273495]

# %%
indices[0]
# Out:
# array([2902266, 2357908, 1746647])

# %%
for ind in indices[0]:
    print(review_df_business_text.text[ind])
# Out:
# I did not care for the smell of this place. While waiting the smell got so bad my wife and I walked out. The smell was a mix between bad seafood and a weird combination of spices. Not normal seafood smells.
# Smell the carpet is disgusting.It is impossible to eat nice by that smell. Very bad attention too.
# Went there recently and the entire restaurant stinks. The smell was so bad we couldn't even enjoy the food or experience. I would not go back until they do something  about that smell.

# %%
review_df_business_text.iloc[indices[0][0]]
# Out:
# business_id                               0StbKjld9f8GbeDRy0fS0A
# text           I did not care for the smell of this place. Wh...
# Name: 2902266, dtype: object

# %% [markdown]
# Respuesta:

# %%
review_df_business_text.business_id.iloc[indices[0][0]]
# Out:
# '0StbKjld9f8GbeDRy0fS0A'

# %% [markdown]
# #C4 - Si tomamos una muestra de negocios con más de 10 reviews y todas sus reviews como un texto concatenado, en términos de distancia de compresión normalizada para esos textos, cuáles son los dos negocios más parecidos? Muestrelos sus textos y distancia.

# %%
business_df = pd.read_csv('/content/drive/MyDrive/TP_Datos_1C2022/business.csv', usecols=['business_id', 'review_count', 'name'])

# %%
business_con_mas_de_10_df = business_df[business_df['review_count'] > 10]

# %%
business_con_mas_de_10_sample_df = business_con_mas_de_10_df.sample(frac=0.008, replace=False, random_state=1)

# %%
review_df = pd.read_csv('/content/drive/MyDrive/TP_Datos_1C2022/review.csv', usecols=['business_id', 'text'])

# %%
business_review_text_df = business_con_mas_de_10_sample_df.merge(review_df).drop(columns='review_count')

# %%
business_review_text_df.head()
# Out:
#               business_id                   name  \
# 0  4DLIC5fF_QXg61Hwv2BPeQ  Mile End Delicatessen
# 1  4DLIC5fF_QXg61Hwv2BPeQ  Mile End Delicatessen
# 2  4DLIC5fF_QXg61Hwv2BPeQ  Mile End Delicatessen
# 3  4DLIC5fF_QXg61Hwv2BPeQ  Mile End Delicatessen
# 4  4DLIC5fF_QXg61Hwv2BPeQ  Mile End Delicatessen
#
#                                                 text
# 0  Such a great addition to downtown. Popped in f...
# 1  Classic NYC style Jewish deli in the Fairlane ...
# 2  If downtown is going to become a pit of bachel...
# 3  The best breakfast we had in Nashville! The po...
# 4  We love Montreal style bagels, which are crust...

# %%
def joinear(serie):
  return ' '.join(serie)

# %%
textos_concatenados = business_review_text_df.groupby('business_id').agg({'text':joinear}).text.to_list()

# %%
import gzip

def compress_size(bytefile):
    return len(gzip.compress(bytefile))

def ncd(obj1, obj2):
    len1 = compress_size(obj1)
    len2 = compress_size(obj2)
    concat_len = len(gzip.compress(obj1+obj2))
    return (concat_len-min(len1, len2))/max(len1, len2)

# %%
from tqdm import tqdm
distancias_totales = []
for i in tqdm(range(len(textos_concatenados))):
  distancias = [ncd(textos_concatenados[j].encode(), textos_concatenados[i].encode()) for j in range(len(textos_concatenados)) if i != j]
  distancias_totales.append(distancias)
# Out:
# 100%|██████████| 511/511 [46:45<00:00,  5.49s/it]

# %%
aux = []
for ind, elemento in enumerate(distancias_totales):
  indice = np.argsort(elemento)[0]
  aux.append((ind, indice, elemento[indice]))

# %%
from operator import itemgetter
min(aux,key=itemgetter(2))
# Out:
# (420, 294, 0.8590177815410669)

# %%
texto_1 = textos_concatenados[420]
texto_2 = textos_concatenados[294]

# %%
business = []
contador = 0
for i in range(len(business_review_text_df)):
  review = business_review_text_df.iloc[i, 2]
  if review in texto_1:
    if len(business) !=0:
      if business_review_text_df.iloc[i, 0] in business:
        continue
    business.append(business_review_text_df.iloc[i, 0])
    contador += 1
  
  elif review in texto_2:
    if len(business) !=0:
      if business_review_text_df.iloc[i, 0] in business:
        continue
    business.append(business_review_text_df.iloc[i, 0])
    contador += 1

  elif contador == 2:
    break

# %%
business
# Out:
# ['oI_0uod6jeq8fJJu8ySFSA', 'YqCQBJgUZHFFHRX1VgU3Ag']

# %%
display(
    business_review_text_df[business_review_text_df['business_id'] == business[0]].head(),
    business_review_text_df[business_review_text_df['business_id'] == business[1]].head()
)
# Out:
#                  business_id         name  \
# 4005  oI_0uod6jeq8fJJu8ySFSA  Panda House
# 4006  oI_0uod6jeq8fJJu8ySFSA  Panda House
# 4007  oI_0uod6jeq8fJJu8ySFSA  Panda House
# 4008  oI_0uod6jeq8fJJu8ySFSA  Panda House
# 4009  oI_0uod6jeq8fJJu8ySFSA  Panda House
#
#                                                    text
# 4005  Came here on my lunch break.. read reviews abo...
# 4006  I was raised in NY and Panda House is by far m...
# 4007  The first thing I noticed when I walked in was...
# 4008  Take out....\nOrdered Hot And Sour soup.. rece...
# 4009  Horrible. I had to throw away all my food. Not...
#                  business_id                name  \
# 7447  YqCQBJgUZHFFHRX1VgU3Ag  Kowloon Restaurant
# 7448  YqCQBJgUZHFFHRX1VgU3Ag  Kowloon Restaurant
# 7449  YqCQBJgUZHFFHRX1VgU3Ag  Kowloon Restaurant
# 7450  YqCQBJgUZHFFHRX1VgU3Ag  Kowloon Restaurant
# 7451  YqCQBJgUZHFFHRX1VgU3Ag  Kowloon Restaurant
#
#                                                    text
# 7447  Very happy to see that they opened their doors...
# 7448  Everything we ordered was really great. Best C...
# 7449  They are open again! \nWe have tried many Chin...
# 7450  They just opened for about a week when I did m...
# 7451  I never got to try this place before the fire ...

# %% [markdown]
# Respuesta:

# %% [markdown]
# Los dos negocios mas parecidos son:
# *   Kowloon Restaurant
# *   Panda House

# %% [markdown]
# Sus textos son:

# %%
texto_1
# Out:
# 'Came here on my lunch break.. read reviews about it on yelp and decided to give it a try.. glad I did.. the food was made to order so it was nice and hot.. staff very friendly and it only took 10 mins.. I order the general tso and noodles and it was amazing plus it came with an egg roll! I was raised in NY and Panda House is by far my favorite NY-style Chinese fast food (you can dine-in too) restaurant in Nashville. I have never been disappointed in the quality of the food, the portions, or the service. They are one of the very few Chinese restaurants in the area who know how to make fried wontons so that they are both crispy on the outside and tender on the inside. The food is never too greasy or heavy with oil or sauce. The first thing I noticed when I walked in was how CLEAN this place looked and smelled! The staff was super fast and friendly ... and the food was fresh, hot and delicious!!!!!! What a pleasant surprise! Take out....\nOrdered Hot And Sour soup.. received WonTon soup! Big difference between the two!\n\nPaid for Dinner size meal.. rec\'d lunch size!!\nWas very bland...\n\nHave to admit.. crab rangoon are good!\nNot worth the $22 Horrible. I had to throw away all my food. Not even joking. I was expecting much better when I read the reviews but my general tsos chicken tasted like it had cleaning chemicals in it and the crab Rangoon was spoiled. Tasted like acidic vomit. I will never go back. Please, if you want Chinese, go somewhere else. Waste of 20 bucks. Finally found a Chinese food place less than 20 minutes from me. I was super excited and ordered most of my favorites: chicken lo mein, pork egg foo young, chicken and broccoli, and egg rolls. \n\n\nOther than that I picked up my food, took it home and it was all still warm by the time I got home. The place was clean and the staff was nice when I arrived to pick up my order. \n\nThe pricing was good for the amount of food you got. \n\nMost all of the food was good! Chicken Lo mein is my favorite and it looked amazing but sadly was very bland which is the only reason I give it 4/5. \n\nOther than that I can defiantly see myself going here again. I love this place it\'s good basic Chinese food! Staff is nice! Only thing that is weird, is the rice color (yellow). But it\'s good. Food is ALWAYS hot and ready! Always ready within 10-15 min! The boneless ribs are LIFE. I\'ve been going here for years and it\'s always consistent with its services. Half way through eating my food I figured I would write a review bc it was so good. I always order the vegetable lo mein (spicy). I\'ve tried soooo many other lo meins out there but this is the one lol I asked for the restroom and they said it\'s out of order. They had it blocked off with tables. I knew it couldn\'t be out of order because the staff would have no restroom if it was. So while they were preparing my order,I moved the tables and found that the restroom as NOT out of order.  English translation: "We do not want our customers using our restrooms."  My message them: "We do not want Nashvillians to eat at your restaurant."\n\nTheir food is your average strip mall Chinese, with the same menu, even. We moved from Miami to Nashville three years ago and had been on the hunt for some cheap, tasty, basic, no fuss chinese takeout and this is the place. It took us years to find this gem. This time we had Boneless Ribs, Honey Chicken, and House fried Rice. The staff is really nice and the food is hot and ready when it says it should be. The crispy noodles are an extra couple of cents on the menu which is lame and I\'d recommend getting a drink elsewhere but aside from that everything is tip top. I love this place! I\'m a repeating customer because I love their crab rangoons, dumplings, seasame chcicken, and sweet and sour chicken. The shrimp plates are amazing too. It\'s literally the best. I would suggest getting chicken plates instead of beef/pork because I had beef and broccoli once and it wasn\'t as good as all the ot ...

# %%
texto_2
# Out:
# "Very happy to see that they opened their doors again after they remodeled.  We ordered take out, they are only offering take out and delivery currently.  The wait time I was given (and everyone that called while I wasn't waiting ) was 25 min. 45 min later my food was ready.  I live about 5 min away and when I got home all of the food had to reheated. However the food was very good. It wasn't the typical oil drenched American Chinese take out. It wasn't as delicious as food I have had in Chinatown but as far as local spots, this is back to being my go to place. Everything we ordered was really great. Best Chinese food we've found in the area so far. They are open again! \nWe have tried many Chinese restaurants in the area since they closed, but nothing ever came close to Kowloon.  We have ordered twice since they  re-opened, and have enjoyed it both times. They just opened for about a week when I did my Lunar New Year  dinner takeout so they had some hiccups.  I'm sure they will sort it out in a few weeks and improve their service.  In terms of food, they are better than most American Chinese food places around here.  It's not too greasy. I like the garlic soy dipping sauce that comes with the fried dumplings  and scallion pancake. Portions are fine.  Overall, their food are better than expected (as a Chinese person reviewing them).  Place looks clean! I never got to try this place before the fire and they closed for a few years. I'm glad that they reopened and I got to order. I got beef chow fun, chicken lo mein, hot and sour soup and wonton soup. The wontons are typical wontons that you would get at most places but the broth is so good! Very flavorful. I love their hot and sour soup. The beef chow fun was a little skimpy on the beef but overall good. My toddler daughter loves the lo mein. Can't wait to try other dishes I didn't get to check Kowloon out before the fire, so i was excited to order once they reopened & was not disappointed! Kowloon has become my go-to for Chinese in the Lansdale area. The food has been consistently delicious, fresh, and less greasy than other places. Their noodle & fried rice entrees and combos come with lots of veggies & good amounts of meat/tofu. Their chicken with garlic sauce & hunan style chicken are especially enjoyable! The woman at the front is always friend & the food is always on time & packaged well for takeout. Fantastic food, friendly service. We are willing to go out of our way for this place for sure After trying many Chinese places in the area, we finally found one that's clearly a step above all others.  I also love Mei Ting for the same reasons, but now live too far away to frequent them any longer.... That said, Kowloon is now our GO-TO Chinese place.  \nMuch higher quality dishes than you usually get around here.  Chicken dishes like the Sesame Chicken are all white meat and not over-breaded like so many other places.  The King Pao is out of this world - flavor, portion size, etc - all on point.  Fried rice was perfect, for lack of a better word, and the crab rangoons are simply phenomenal.  \nThis is, and will always be, our Chinese take-out place of choice.  \nYou'll never be disappointed with Kowloon! Definitely worth the money, and it has tons of delicious options. One of the only places you can get pork buns in the area too! So excited that Kowloon is open again!!  Food is always amazing!!   They are perfectly set up for takeout or delivery during this difficult time. Happy we discovered Kowloon this weekend! Saw a bunch of good reviews online, so decided to try it. Really enjoyed our food and it wasn't greasy like Chinese food sometimes is. My favorite was the Singapore noodles. So tasty! Can't wait to go back! I was in the area so I called in an order to pick up on my way home. I ordered eggplant with garlic sauce and some lo mein. The order was just ready when I got there and the person that I picked up from was courteous and friendly. The food was well prepared and t ...

# %% [markdown]
# La ditancia es:
#
# `0.8590177815410669`

# %% [markdown]
# #C5

# %%
review_text_df = pd.read_csv('/content/drive/MyDrive/TP_Datos_1C2022/review.csv', usecols=['text'])

# %%
review_text_df.head()
# Out:
#                                                 text
# 0  If you decide to eat here, just be aware it is...
# 1  Cute interior and owner (?) gave us tour of up...
# 2  I was really between 3 and 4 stars for this on...
# 3  First time there and it was excellent!!! It fe...
# 4  Great burgers,fries and salad!  Burgers have a...

# %%
review_text_sample_df = review_text_df.sample(frac=0.8, replace=False, random_state=1)

# %%
textos_concatenados = review_text_sample_df.text.str.cat(sep=' ')

# %%
# !pip install zstandard
import zstandard

def compress_size(bytefile):
    return len(zstandard.compress(bytefile))
# Out:
# Requirement already satisfied: zstandard in /usr/local/lib/python3.7/dist-packages (0.17.0)

# %%
# %%timeit
zstandard.compress(textos_concatenados.encode())
# Out:
# 1 loop, best of 5: 17.8 s per loop

# %%
compresion = zstandard.compress(textos_concatenados.encode())

# %%
# %%timeit
zstandard.decompress(compresion)
# Out:
# 1 loop, best of 5: 3.58 s per loop

# %%
len(textos_concatenados) / compress_size(textos_concatenados.encode())
# Out:
# 2.731232498887861

# %%
len(compresion) / len(textos_concatenados)
# Out:
# 0.36613506920673833

# %%
from scipy.stats import entropy
def calcular_entropia(texto):
  res = {}
  probas = []
  longitud = len(texto)
  
  for caracter in texto:
    res[caracter] = res.get(caracter, 0) + 1
  
  for caracter in res:
    frecuencia = res[caracter]
    proba = frecuencia/longitud
    probas.append(proba)
  
  return entropy(probas, base=2)

# %%
entropia = calcular_entropia(textos_concatenados) #son bits

# %%
entropia / 8
# Out:
# 0.5557727191368754

# %%
8 / entropia
# Out:
# 1.7992966649262978

# %% [markdown]
# ###¿De cuanto es el ratio de compresión?

# %% [markdown]
# El ratio de compresion es:
#
# $2.7312324988878614$.

# %% [markdown]
# ###¿Cuánto tarda en comprimir y descomprimir (por separado)?

# %% [markdown]
# A partir de la ejecucion de colab, comprimir tarda mas o menos 2 minutos y descomprimir tarda 32 segundos.
#
# `%%timeit` ayuda a ver que cada iteracion del proceso de descompresión tarda menos que el de compresión.

# %% [markdown]
# ###¿Cuánto ocupa cada carácter en promedio una vez comprimido?

# %% [markdown]
# Una vez comprimido, cada caracter en promedio ocupa:
#
# $0.36613506920673833$ bytes.

# %% [markdown]
# ###Si tomamos la entropía base dos para los caracteres ¿cuánto da? ¿cuantos bytes por caracter son esos?

# %% [markdown]
# La entropia es:
#
# $4.446181753095003$ bits
#
# En terminos de bytes por caracter (asumiendo que 8 bits son un byte):
#
# $0.5557727191368754$ bytes.

# %% [markdown]
# ###Si utilizaramos un compresor aritmético por caracter, aproximadamente ¿cuál sería el ratio de compresión en el caso más optimista?

# %% [markdown]
# El compresor aritmético en el mejor de los casos lleva cada byte a la entropia de shannon bits, por lo que el ratio de compresión seria (en el caso más optimista):
#
# $\frac{len(texto)*8}{len(texto)*entropia} = \frac{8}{entropia} = 1.7992966649262978$

# %% [markdown]
# ###¿Cúal algoritmo de compresión de los dos sería mejor?

# %% [markdown]
# Entre `zstandard` y `el compresor aritmético`, el mejor compresor es el primero porque tiene un ratio de compresión mayor.
